# %%
import pandas as pd

# %%
table_GDP = pd.read_html('https://www.spotrac.com/nba/contracts/sort-value/drafted/limit-500/')[0]

# %%
table_GDP
# Out:
#      Rank                                             Player  Signed Age  Yrs  \
# 0       1  Giannis Antetokounmpo  Power Forward | 2021-20...          26    5
# 1       2  Russell Westbrook  Point Guard | 2018-2022 (FA...          28    5
# 2       3         Rudy Gobert  Center | 2021-2025 (FA: 2026)          28    5
# 3       4  Stephen Curry  Point Guard | 2017-2021 (FA: 2022)          29    5
# 4       5  Anthony Davis  Power Forward | 2020-2024 (FA: ...          27    5
# ..    ...                                                ...         ...  ...
# 369   369  Frank Kaminsky  Center | 2020-2020 (FA: 2021) ...          27    1
# 370   371  Emmanuel Mudiay  Point Guard | 2019-2019 (FA: ...          23    1
# 371   371   Willy Hernangomez  Center | 2020-2020 (FA: 2021)          26    1
# 372   373         Harry Giles  Center | 2020-2020 (FA: 2021)          22    1
# 373   373  Sterling Brown  Shooting Guard | 2020-2020 (FA...          25    1
#
# ...
